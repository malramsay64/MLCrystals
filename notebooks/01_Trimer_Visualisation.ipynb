# %% [markdown]
# # Visualisation of Trimer Dataset

# %%
from sdanalysis.figures import plot_frame, output_notebook, show
from sdanalysis import HoomdFrame
import gsd.hoomd

output_notebook()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-112a0c604678> in <module>
# ----> 1 from sdanalysis.figures import plot_frame, output_notebook, show
#       2 from sdanalysis import HoomdFrame
#       3 import gsd.hoomd
#       4
#       5 output_notebook()
#
# ImportError: cannot import name 'output_notebook'

# %%
fname = "../data/simulation/trimer/dump-Trimer-P1.00-T0.30-p2.gsd"
with gsd.hoomd.open(fname) as trj:
    snap = HoomdFrame(trj[0])

# %%
show(plot_frame(snap))
# Out:
#   <div class="bk-root" id="bcf542e7-0b22-4a50-93cf-7713db91f1b6"></div>
